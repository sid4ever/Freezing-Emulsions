# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience
import os
import pims
import trackpy as tp
import time
import skimage as sk
from IPython import display
from IPython.display import clear_output
import ipywidgets as widgets

# %%
from IPython.display import display

# %%
sample = 'ST 18.001 E'

# %%
filename = 'Z:/PhD/Experiments & Results/Data Complete/data/'+ sample + '.tif'
frames_solute = pims.TiffStack_pil(filename)
plt.imshow(frames_solute[10])
# The x-axis is horizontal, the y-axis vertical

# %%
clear_output()
  
# Create an empty dataframe to save the concentration profile results
#concentration_profile = pd.DataFrame(columns=['intensity', 'norm_intensity']) 
nbFrames=np.shape(frames_solute)[0]
concentration_profile=np.zeros(100)

#for i in range(100):
for i in np.r_[:nbFrames]:

    concentration_profile[i] = np.average(frames_solute[i])

# %%
cp5 = concentration_profile
#CP1= 18C
#CP2= 18A
#cp3 =18B
#CP4 =18D
#CP5 =18E

# %%
plt.plot(concentration_profile)
plt.ylim(246.5,247)
plt.xlabel(r'Time (sec)')
plt.ylabel(r'Instensity (a.u.)')
plt.savefig(sample+ '.png',dpi = 300)

# %%
plt.figure()

plt.plot(cp2, label ='I = 1')
plt.plot(cp3, label ='I = 1')
plt.plot(cp1, label ='I = 5')
plt.plot(cp4, label ='I = 10')
plt.plot(cp5, label ='I = 20')
plt.xlabel(r'Time (sec)')
plt.ylabel(r'Instensity (a.u.)')
plt.savefig('Master Curve.png',figsize=(15, 15),dpi = 300)

plt.subplot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot of the data
fig = plt.figure()
ax = fig.add_axes([0.2, 0.2, 0.6, 0.75])
ax.plot(cp2, label ='I = 1')
ax.plot(cp3, label ='I = 1')
ax.plot(cp1, label ='I = 5')
ax.plot(cp4, label ='I = 10')
ax.plot(cp5, label ='I = 20')
ax.set_xlabel('Time (sec)')
ax.set_ylabel('Instensity (a.u.)')
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.savefig('Master Curve 2.png',dpi = 300)

# %%
x =np.arange(len(frames_solute[0]))
np.shape(concentration_profile)
np.shape(frames_solute)
# Out:
# (100, 1664, 1664)

# %%
plt.plot(df.norm_intensity)
plt.xlabel(r'Pixels')
plt.xlim(1,1663)
plt.ylabel('Intensity (a.u.)')
# Out:
# Text(0,0.5,'Intensity (a.u.)')

# %%
file_name = 'Z:\PhD\Experiments & Results\Data Complete\SENB_entaille_130N.txt'

# %%
f =np.loadtxt(file_name, skiprows=1)[:,1:]

# %%
x=np.loadtxt(file_name)[0,1:]

# %%
y=np.loadtxt(file_name, skiprows=1)[:,0]

# %%
xx,yy = np.meshgrid(x,y)

# %%
import matplotlib.pyplot as plt
#pcolormesh of interpolated uniform grid with log colormap
plt.figure
plt.pcolormesh(yy,xx,f, cmap='plasma')
plt.savefig('filename.png', dpi = 300)
plt.show()

# %%
plt.scatter(yy, xx, c=f,cmap='rainbow')
